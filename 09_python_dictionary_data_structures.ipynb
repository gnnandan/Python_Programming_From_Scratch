# %% [markdown]
# ## Dictionary
#
# **Important Message**
#
# - 🔰 Notes Link - [Python Learning From Zero to Hero](https://gnnandan.notion.site/Python-Learning-b3aa7ed958fd44659aa1be95f0f225a6)
# - 🔰 Open Source Developers Community Link (OSDC) - [Curious Developers Community](https://linktr.ee/curiousdevelopers.community)
# - 🔰 Official Website - [Curious Community Ecosystem](https://curiousdevelopers.in)

# %%
# creating dictionary
myDict = {1:"One",2:"Two",3:"Three",4:"Four",5:"Five"}
print(myDict)

# checking datatype
print(type(myDict))

# accessing elements
print(myDict[2])

# accessing element with get property
print(myDict.get(2))

# accessing all the keys
print(myDict.keys())

# accessing all the values
print(myDict.values())

# accessing all the Keys, Values
print(myDict.items())

# updating the element

myDict[2] = "TWO"
print("After updating the element: {}".format(myDict))
myDict.update({3:"THREE"})
print("After updating using update method the element: {}".format(myDict))

# removing the element
myDict.pop(3)
print("After removing the element: {}".format(myDict))

# iterating over all elements
print("Iterating over keys")
for key in myDict.keys():
  print("Keys are {} ".format(key))

print("Iterating over values")
for values in myDict.values():
  print("Values are {} ".format(values))

print("Iterating over all elements")
for key,values in myDict.items():
  print("Keys are {} and Values are {}".format(key,values))
# Out:
# {1: 'One', 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five'}
# <class 'dict'>
# Two
# Two
# dict_keys([1, 2, 3, 4, 5])
# dict_values(['One', 'Two', 'Three', 'Four', 'Five'])
# dict_items([(1, 'One'), (2, 'Two'), (3, 'Three'), (4, 'Four'), (5, 'Five')])
# After updating the element: {1: 'One', 2: 'TWO', 3: 'Three', 4: 'Four', 5: 'Five'}
# After updating using update method the element: {1: 'One', 2: 'TWO', 3: 'THREE', 4: 'Four', 5: 'Five'}
# After removing the element: {1: 'One', 2: 'TWO', 4: 'Four', 5: 'Five'}
# Iterating over keys
# Keys are 1
# Keys are 2
# Keys are 4
# Keys are 5
# Iterating over values
# Values are One
# Values are TWO
# Values are Four
# Values are Five
# Iterating over all elements
# Keys are 1 and Values are One
# Keys are 2 and Values are TWO
# Keys are 4 and Values are Four
# Keys are 5 and Values are Five

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# ## Important Methods
# 1. clear() - Removes all the elements from the dictionary
# 2. copy() - Returns a copy of the dictionary
# 3. fromkeys(keys, value -> optional) - Returns a dictionary with the specified keys and value
# 4. get(keyname, value -> optional) - Returns the value of the specified key
# 5. items() - Returns a list containing a tuple for each key value pair
# 6. keys() - Returns a list containing the dictionary's keys
# 7. pop(keyname, defaultvalue -> optional) - Removes the element with the specified key
# 8. popitem() - Removes the last inserted key-value pair
# 9. setdefault(keyname, value -> optional) - Returns the value of the specified key. If the key does not
# 10. exist: insert the key, with the specified value
# 11. update() - Updates the dictionary with the specified key-value pairs
# 12. values() - Returns a list of all the values in the dictionary

# %%
myDict = {1:"One",2:"Two",3:"Three",4:"Four",5:"Five"}

# get()
print(myDict.get(3))

# update()
newDict = ["one","two","three"]
myDict.update({2:newDict})
print("After updating the dictionary: {}".format(myDict))
myDict.update({1:"ONE"})
print("After updating the dictionary: {}".format(myDict))

# keys()
print(myDict.keys())

# values()
print(myDict.values())

# items()
print(myDict.items())

# fromkeys()
dict1 = {1:"One",2:"Two",3:"Three",4:"Four",5:"Five"}
dict2 = {1:"aaa",2:"bbb",3:"ccc",4:"ddd",5:"eee"}
dict1.fromkeys(dict1,dict2)

# copy
copyDict = myDict.copy()
print("Copied dictionary: {}".format(copyDict))

# pop()
myDict.pop(2,"notfound")
print("After popping element {}".format(myDict))

# popitem()
myDict.popitem()
print("After popping element {}".format(myDict))

myDict.clear()
print("After clearing dictionary {}".format(myDict))
# Out:
# Three
# After updating the dictionary: {1: 'One', 2: ['one', 'two', 'three'], 3: 'Three', 4: 'Four', 5: 'Five'}
# After updating the dictionary: {1: 'ONE', 2: ['one', 'two', 'three'], 3: 'Three', 4: 'Four', 5: 'Five'}
# dict_keys([1, 2, 3, 4, 5])
# dict_values(['ONE', ['one', 'two', 'three'], 'Three', 'Four', 'Five'])
# dict_items([(1, 'ONE'), (2, ['one', 'two', 'three']), (3, 'Three'), (4, 'Four'), (5, 'Five')])
# Copied dictionary: {1: 'ONE', 2: ['one', 'two', 'three'], 3: 'Three', 4: 'Four', 5: 'Five'}
# After popping element {1: 'ONE', 3: 'Three', 4: 'Four', 5: 'Five'}
# After popping element {1: 'ONE', 3: 'Three', 4: 'Four'}
# After clearing dictionary {}

# %% [markdown]
# ## Nested Dictionary
#
# myfamily = {
#   "child1" : {
#     "name" : "Emil",
#     "year" : 2004
#   },
#   "child2" : {
#     "name" : "Tobias",
#     "year" : 2007
#   },
#   "child3" : {
#     "name" : "Linus",
#     "year" : 2011
#   }
# }

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# accessing keys in Nested Dictionary
print("Keys in Nested Dictionary")
for data in myfamily.keys():
  print(data)
  
# accessing values in Nested Dictionary
print("Values in Nested Dictionary")
for values in myfamily.values():
  print(values)

print("Keys & Values in Nested Dictionary")
for keys,values in myfamily.items():
  print(keys," - ",values)
  
print("Accessing individual element - {}".format(myfamily["child1"]["name"]))
print("Accessing individual element - {}".format(myfamily["child2"]["year"]))
# Out:
# Keys in Nested Dictionary
# child1
# child2
# child3
# Values in Nested Dictionary
# {'name': 'Emil', 'year': 2004}
# {'name': 'Tobias', 'year': 2007}
# {'name': 'Linus', 'year': 2011}
# Keys & Values in Nested Dictionary
# child1  -  {'name': 'Emil', 'year': 2004}
# child2  -  {'name': 'Tobias', 'year': 2007}
# child3  -  {'name': 'Linus', 'year': 2011}
# Accessing individual element - Emil
# Accessing individual element - 2007
